# %%
from pypekit import Task, Repository, CachedExecutor, Pipeline

class DataLoader(Task):
    input_types = ["source"]
    output_types = ["raw"]

    def run(self, _):
        print(f"Running DataLoader")
        return "output"

class Processor(Task):
    input_types = ["raw", "processed"]
    output_types = ["processed"]

    def run(self, _):
        print(f"Running Processor")
        return "output"

class Classifier(Task):
    input_types = ["raw", "processed"]
    output_types = ["sink", "processed"]

    def run(self, _):
        print(f"Running Classifier")
        return "output"

repository = Repository([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline_dict = repository.build_pipelines()
for pipeline in pipeline_dict.values():
    print(pipeline)

executor = CachedExecutor(pipeline_dict, verbose=True)
executor.run()

executor.results
# Out:
# Pipeline(id=b30c3f44e0364eb1a2cbe015e8793f7f, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=19c24dd370854609aacdc680aadb116f, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=cd3cabd994a9453786d6eb916b25825e, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=41128882c4dd417ca0ee6254b03fe6db, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=555e70f5a04f4b318acc4b76a8f72c45, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=763677e34a2f498e981cd989046f8897, tasks=['data_loader', 'processor_1', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=4b13161dde754f9f8ffc0d25efb73e4b, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=d138b9f45463493eb2047471673580b3, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=6111fd4163324586aacba13fb2da592e, tasks=['data_loader', 'processor_1', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=b5bbbc5702f34480929abe6022acea95, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=98ca0542223144388503e18735fd7bc7, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=a41e1133ed234994983b202e0446025f, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=a75bd2294473433aa9f9c88b51d664d6, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=f4a99535f6d243b1bc2b7768b2957f5e, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=41b1e384e2074b70a8da3f1a9c6b0aaf, tasks=['data_loader', 'processor_2', 'classifier_1'])
# Pipeline(id=6e029851dd314256b39f27c623250eff, tasks=['data_loader', 'processor_2', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=4e99894d042e4d96bf6fddd0bdf4d2bc, tasks=['data_loader', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=5b3b6642976746ecbefcac713bc0037b, tasks=['data_loader', 'processor_2', 'classifier_2'])
# Pipeline(id=e32220921c504477a53f8f63090a02cb, tasks=['data_loader', 'processor_2', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=9625ef36264141cb80f86c91a0a0e87d, tasks=['data_loader', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=43e0cec41d3a4ae79d13c2d9a926a8ea, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=7eb479ba607e4b32863031b518553e28, tasks=['data_loader', 'classifier_1', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=b1ba5a7cd9044a589f89b75202ad728f, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=1a2d22d346384736b08f8be76763dfdf, tasks=['data_loader', 'classifier_1', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=de7bf5e0df5a484dbac29dd1156c21fa, tasks=['data_loader', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=809daf249f9a48f4964e8ad8381099e7, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=b2b1234f5862423aba4b680a75b92ea0, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=e3f148b7c7064ff2807d6594b593c6fa, tasks=['data_loader', 'classifier_2', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=4be6af3845d54b89bf8cc378e9b260bb, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=0d302f7720ac4b2c8599d1a36e73438c, tasks=['data_loader', 'classifier_2', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=05ff2c271b664bf29e4dd282b36bdbd2, tasks=['data_loader', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=55582ed87679492f9a131e45f5b6cd54, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Running DataLoader
# Running Processor
# Running Processor
# Running Classifier
# Pipeline b30c3f44e0364eb1a2cbe015e8793f7f completed.
# Running Classifier
# Pipeline 19c24dd370854609aacdc680aadb116f completed.
# Running Classifier
# Pipeline cd3cabd994a9453786d6eb916b25825e completed.
# Running Classifier
# Pipeline 41128882c4dd417ca0ee6254b03fe6db completed.
# Running Classifier
# Pipeline 555e70f5a04f4b318acc4b76a8f72c45 completed.
# Running Processor
# Running Classifier
# Pipeline 763677e34a2f498e981cd989046f8897 completed.
# Running Classifier
# Pipeline 4b13161dde754f9f8ffc0d25efb73e4b completed.
# Running Classifier
# Pipeline d138b9f45463493eb2047471673580b3 completed.
# Running Processor
# Running Classifier
# Pipeline 6111fd4163324586aacba13fb2da592e completed.
# Running Classifier
# Pipeline b5bbbc5702f34480929abe6022acea95 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 98ca0542223144388503e18735fd7bc7 completed.
# Running Classifier
# Pipeline a41e1133ed234994983b202e0446025f completed.
# Running Classifier
# Pipeline a75bd2294473433aa9f9c88b51d664d6 completed.
# Running Classifier
# Pipeline f4a99535f6d243b1bc2b7768b2957f5e completed.
# Running Classifier
# Pipeline 41b1e384e2074b70a8da3f1a9c6b0aaf completed.
# Running Processor
# Running Classifier
# Pipeline 6e029851dd314256b39f27c623250eff completed.
# Running Classifier
# Pipeline 4e99894d042e4d96bf6fddd0bdf4d2bc completed.
# Running Classifier
# Pipeline 5b3b6642976746ecbefcac713bc0037b completed.
# Running Processor
# Running Classifier
# Pipeline e32220921c504477a53f8f63090a02cb completed.
# Running Classifier
# Pipeline 9625ef36264141cb80f86c91a0a0e87d completed.
# Running Classifier
# Pipeline 43e0cec41d3a4ae79d13c2d9a926a8ea completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 7eb479ba607e4b32863031b518553e28 completed.
# Running Classifier
# Pipeline b1ba5a7cd9044a589f89b75202ad728f completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 1a2d22d346384736b08f8be76763dfdf completed.
# Running Classifier
# Pipeline de7bf5e0df5a484dbac29dd1156c21fa completed.
# Running Classifier
# Pipeline 809daf249f9a48f4964e8ad8381099e7 completed.
# Running Classifier
# Pipeline b2b1234f5862423aba4b680a75b92ea0 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline e3f148b7c7064ff2807d6594b593c6fa completed.
# Running Classifier
# Pipeline 4be6af3845d54b89bf8cc378e9b260bb completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 0d302f7720ac4b2c8599d1a36e73438c completed.
# Running Classifier
# Pipeline 05ff2c271b664bf29e4dd282b36bdbd2 completed.
# Running Classifier
# Pipeline 55582ed87679492f9a131e45f5b6cd54 completed.
# {'b30c3f44e0364eb1a2cbe015e8793f7f': {'pipeline_id': 'b30c3f44e0364eb1a2cbe015e8793f7f',
#   'output': 'output',
#   'runtime': 3.3500000000075136e-05,
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_1']},
#  '19c24dd370854609aacdc680aadb116f': {'pipeline_id': '19c24dd370854609aacdc680aadb116f',
#   'output': 'output',
#   'runtime': 3.9100000000069635e-05,
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_1',
#    'classifier_2']},
#  'cd3cabd994a9453786d6eb916b25825e': {'pipeline_id': 'cd3cabd994a9453786d6eb916b25825e',
#   'output': 'output',
#   'runtime': 3.3200000000011e-05,
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_2']},
#  '41128882c4dd417ca0ee6254b03fe6db': {'pipeline_id': '41128882c4dd417ca0ee6254b03fe6db',
#   'output': 'output',
#   'runtime': 3.790000000003513e-05,
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_2',
#    'classifier_1']},
#  '555e70f5a04f4b318acc4b76a8f72c45': {'pipeline_id': '555e70f5a04f4b318acc4b76a8f72c45',
#   'output': 'output',
#   'runtime': 2.8000000000083514e-05,
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  '763677e34a2f498e981cd989046f8897': {'pipeline_id': '763677e34a2f498e981cd989046f8897',
#   'output': 'output',
#   'runtime': 3.750000000013465e-05,
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_1',
#    'processor_2',
#    'classifier_2']},
#  '4b13161dde754f9f8ffc0d25efb73e4b': {'pipeline_id': '4b13161dde754f9f8ffc0d25efb73e4b',
#   'output': 'output',
#   'runtime': 3.280000000005501e-05,
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  'd138b9f45463493eb2047471673580b3': {'pipeline_id': 'd138b9f45463493eb2047471673580b3',
#   'output': 'output',
#   'runtime': 2.7800000000077763e-05,
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  '6111fd4163324586aacba13fb2da592e': {'pipeline_id': '6111fd4163324586aacba13fb2da592e',
#   'output': 'output',
#   'runtime': 3.700000000012027e-05,
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_2',
#    'processor_2',
#    'classifier_1']},
#  'b5bbbc5702f34480929abe6022acea95': {'pipeline_id': 'b5bbbc5702f34480929abe6022acea95',
#   'output': 'output',
#   'runtime': 3.260000000010477e-05,
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  '98ca0542223144388503e18735fd7bc7': {'pipeline_id': '98ca0542223144388503e18735fd7bc7',
#   'output': 'output',
#   'runtime': 3.0000000000085514e-05,
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_1']},
#  'a41e1133ed234994983b202e0446025f': {'pipeline_id': 'a41e1133ed234994983b202e0446025f',
#   'output': 'output',
#   'runtime': 3.560000000008001e-05,
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_1',
#    'classifier_2']},
#  'a75bd2294473433aa9f9c88b51d664d6': {'pipeline_id': 'a75bd2294473433aa9f9c88b51d664d6',
#   'output': 'output',
#   'runtime': 3.0200000000091265e-05,
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_2']},
#  'f4a99535f6d243b1bc2b7768b2957f5e': {'pipeline_id': 'f4a99535f6d243b1bc2b7768b2957f5e',
#   'output': 'output',
#   'runtime': 3.500000000011827e-05,
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_2',
#    'classifier_1']},
#  '41b1e384e2074b70a8da3f1a9c6b0aaf': {'pipeline_id': '41b1e384e2074b70a8da3f1a9c6b0aaf',
#   'output': 'output',
#   'runtime': 2.5100000000055633e-05,
#   'tasks': ['data_loader', 'processor_2', 'classifier_1']},
#  '6e029851dd314256b39f27c623250eff': {'pipeline_id': '6e029851dd314256b39f27c623250eff',
#   'output': 'output',
#   'runtime': 3.460000000010677e-05,
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_1',
#    'processor_1',
#    'classifier_2']},
#  '4e99894d042e4d96bf6fddd0bdf4d2bc': {'pipeline_id': '4e99894d042e4d96bf6fddd0bdf4d2bc',
#   'output': 'output',
#   'runtime': 2.9700000000021376e-05,
#   'tasks': ['data_loader', 'processor_2', 'classifier_1', 'classifier_2']},
#  '5b3b6642976746ecbefcac713bc0037b': {'pipeline_id': '5b3b6642976746ecbefcac713bc0037b',
#   'output': 'output',
#   'runtime': 2.56000000000145e-05,
#   'tasks': ['data_loader', 'processor_2', 'classifier_2']},
#  'e32220921c504477a53f8f63090a02cb': {'pipeline_id': 'e32220921c504477a53f8f63090a02cb',
#   'output': 'output',
#   'runtime': 3.529999999996036e-05,
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_2',
#    'processor_1',
#    'classifier_1']},
#  '9625ef36264141cb80f86c91a0a0e87d': {'pipeline_id': '9625ef36264141cb80f86c91a0a0e87d',
#   'output': 'output',
#   'runtime': 3.049999999998887e-05,
#   'tasks': ['data_loader', 'processor_2', 'classifier_2', 'classifier_1']},
#  '43e0cec41d3a4ae79d13c2d9a926a8ea': {'pipeline_id': '43e0cec41d3a4ae79d13c2d9a926a8ea',
#   'output': 'output',
#   'runtime': 2.0600000000037255e-05,
#   'tasks': ['data_loader', 'classifier_1']},
#  '7eb479ba607e4b32863031b518553e28': {'pipeline_id': '7eb479ba607e4b32863031b518553e28',
#   'output': 'output',
#   'runtime': 3.4799999999945985e-05,
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_1',
#    'processor_2',
#    'classifier_2']},
#  'b1ba5a7cd9044a589f89b75202ad728f': {'pipeline_id': 'b1ba5a7cd9044a589f89b75202ad728f',
#   'output': 'output',
#   'runtime': 3.0200000000035754e-05,
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  '1a2d22d346384736b08f8be76763dfdf': {'pipeline_id': '1a2d22d346384736b08f8be76763dfdf',
#   'output': 'output',
#   'runtime': 5.869999999996711e-05,
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_2',
#    'processor_1',
#    'classifier_2']},
#  'de7bf5e0df5a484dbac29dd1156c21fa': {'pipeline_id': 'de7bf5e0df5a484dbac29dd1156c21fa',
#   'output': 'output',
#   'runtime': 3.140000000001475e-05,
#   'tasks': ['data_loader', 'classifier_1', 'processor_2', 'classifier_2']},
#  '809daf249f9a48f4964e8ad8381099e7': {'pipeline_id': '809daf249f9a48f4964e8ad8381099e7',
#   'output': 'output',
#   'runtime': 2.560000000007001e-05,
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  'b2b1234f5862423aba4b680a75b92ea0': {'pipeline_id': 'b2b1234f5862423aba4b680a75b92ea0',
#   'output': 'output',
#   'runtime': 2.089999999999037e-05,
#   'tasks': ['data_loader', 'classifier_2']},
#  'e3f148b7c7064ff2807d6594b593c6fa': {'pipeline_id': 'e3f148b7c7064ff2807d6594b593c6fa',
#   'output': 'output',
#   'runtime': 3.6099999999927856e-05,
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_1',
#    'processor_2',
#    'classifier_1']},
#  '4be6af3845d54b89bf8cc378e9b260bb': {'pipeline_id': '4be6af3845d54b89bf8cc378e9b260bb',
#   'output': 'output',
#   'runtime': 3.0799999999941985e-05,
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  '0d302f7720ac4b2c8599d1a36e73438c': {'pipeline_id': '0d302f7720ac4b2c8599d1a36e73438c',
#   'output': 'output',
#   'runtime': 3.540000000007426e-05,
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_2',
#    'processor_1',
#    'classifier_1']},
#  '05ff2c271b664bf29e4dd282b36bdbd2': {'pipeline_id': '05ff2c271b664bf29e4dd282b36bdbd2',
#   'output': 'output',
#   'runtime': 3.0400000000041505e-05,
#   'tasks': ['data_loader', 'classifier_2', 'processor_2', 'classifier_1']},
#  '55582ed87679492f9a131e45f5b6cd54': {'pipeline_id': '55582ed87679492f9a131e45f5b6cd54',
#   'output': 'output',
#   'runtime': 2.5499999999956113e-05,
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']}}

# %%
n = 4

repository = Repository(
    [(f"data_loader_{i}", DataLoader()) for i in range(n)] +
    [(f"processor_{i}", Processor()) for i in range(n)] +
    [(f"classifier_{i}", Classifier()) for i in range(n)] 
)

from time import time
start = time()
pipelines = repository.build_pipelines()
print(f"Built {len(pipelines)} pipelines in {time() - start:.2f} seconds")
# Out:
# Built 219200 pipelines in 2.85 seconds

# %%
pipeline = Pipeline([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline
# Out:
# Pipeline(id=8975dd906cb24f51ae51b8d5486fc94f, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])

# %%
print(repository)
print(executor)
# Out:
# Repository(tasks=['data_loader_0', 'data_loader_1', 'data_loader_2', 'data_loader_3', 'processor_0', 'processor_1', 'processor_2', 'processor_3', 'classifier_0', 'classifier_1', 'classifier_2', 'classifier_3'], pipelines=219200)
# CachedExecutor(pipelines=32)

# %%
executor2 = CachedExecutor(pipeline_dict, cache=executor.cache, verbose=True)
executor2.run();
# Out:
# Pipeline b30c3f44e0364eb1a2cbe015e8793f7f completed.
# Pipeline 19c24dd370854609aacdc680aadb116f completed.
# Pipeline cd3cabd994a9453786d6eb916b25825e completed.
# Pipeline 41128882c4dd417ca0ee6254b03fe6db completed.
# Pipeline 555e70f5a04f4b318acc4b76a8f72c45 completed.
# Pipeline 763677e34a2f498e981cd989046f8897 completed.
# Pipeline 4b13161dde754f9f8ffc0d25efb73e4b completed.
# Pipeline d138b9f45463493eb2047471673580b3 completed.
# Pipeline 6111fd4163324586aacba13fb2da592e completed.
# Pipeline b5bbbc5702f34480929abe6022acea95 completed.
# Pipeline 98ca0542223144388503e18735fd7bc7 completed.
# Pipeline a41e1133ed234994983b202e0446025f completed.
# Pipeline a75bd2294473433aa9f9c88b51d664d6 completed.
# Pipeline f4a99535f6d243b1bc2b7768b2957f5e completed.
# Pipeline 41b1e384e2074b70a8da3f1a9c6b0aaf completed.
# Pipeline 6e029851dd314256b39f27c623250eff completed.
# Pipeline 4e99894d042e4d96bf6fddd0bdf4d2bc completed.
# Pipeline 5b3b6642976746ecbefcac713bc0037b completed.
# Pipeline e32220921c504477a53f8f63090a02cb completed.
# Pipeline 9625ef36264141cb80f86c91a0a0e87d completed.
# Pipeline 43e0cec41d3a4ae79d13c2d9a926a8ea completed.
# Pipeline 7eb479ba607e4b32863031b518553e28 completed.
# Pipeline b1ba5a7cd9044a589f89b75202ad728f completed.
# Pipeline 1a2d22d346384736b08f8be76763dfdf completed.
# Pipeline de7bf5e0df5a484dbac29dd1156c21fa completed.
# Pipeline 809daf249f9a48f4964e8ad8381099e7 completed.
# Pipeline b2b1234f5862423aba4b680a75b92ea0 completed.
# Pipeline e3f148b7c7064ff2807d6594b593c6fa completed.
# Pipeline 4be6af3845d54b89bf8cc378e9b260bb completed.
# Pipeline 0d302f7720ac4b2c8599d1a36e73438c completed.
# Pipeline 05ff2c271b664bf29e4dd282b36bdbd2 completed.
# Pipeline 55582ed87679492f9a131e45f5b6cd54 completed.

# %%
repository = Repository([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("pipeline", pipeline),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline_dict = repository.build_pipelines()
for pipeline in pipeline_dict.values():
    print(pipeline)
# Out:
# Pipeline(id=e309286563574e3b86727e293a4eb8bf, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=26950be8752245aa97be3854bc47c9ce, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=521a87bda75f48378f4766e266d1de27, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=8c20fc91a49244b8822562584efbb765, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=fa53b49140d04388be6b712f091d00a5, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=57511eef01804b7cb62f83cca3affe98, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=ccdc5cf0ddae49898f14df082c85da09, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=49d569340b394b34b8dd2a9351e51cc8, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=b78d3f0057a84ec6b9e88e8afb460e44, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=ba1193acee584b24bb8de607959847d7, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Pipeline(id=893224edfd2247eba56ee0f4c6f14ea6, tasks=['pipeline'])
# Pipeline(id=f5d03dbb815a479fbb0572cabf14d357, tasks=['pipeline', 'processor_1', 'classifier_1'])
# Pipeline(id=5324043252ea4581a39ca0c70d4b1052, tasks=['pipeline', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=92e6543ec4964d288302cbfac51de2f7, tasks=['pipeline', 'processor_1', 'classifier_2'])
# Pipeline(id=85a71cda0adb4bd98291f1cb246b4167, tasks=['pipeline', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=d143c7b3abff4ff1bc099d6a96e7c9a0, tasks=['pipeline', 'classifier_1'])
# Pipeline(id=0c5b99edd17b4e68aef0e3330705cbd6, tasks=['pipeline', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=0b75a9dc323e46d2a8bc0c8137665cc2, tasks=['pipeline', 'classifier_1', 'classifier_2'])
# Pipeline(id=6d3e8ae92c294b94884002c552ea01a4, tasks=['pipeline', 'classifier_2'])
# Pipeline(id=3f75a06264d749b7bdaf8db1e7bed963, tasks=['pipeline', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=085ddc184d684347ad325d4bcc6d7b0c, tasks=['pipeline', 'classifier_2', 'classifier_1'])
