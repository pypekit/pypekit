ed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline f5b828f0-6ebd-44c0-9af0-718c7e4ff777 completed.
# Running Classifier
# Pipeline 36d728ab-6e88-40cd-8cd0-4e978b254d0d completed.
# Running Classifier
# Pipeline 6056c2d7-8285-4e6c-b7d8-b45057ce43f6 completed.
# Running Classifier
# Pipeline 52d3e82b-2e27-4af8-a8fa-287b1b3669d0 completed.
# Running Classifier
# Pipeline fbb12f51-6335-48f6-8e67-4cac11a1bf03 completed.
# Running Processor
# Running Classifier
# Pipeline 6c7074e4-3dee-4748-bb6d-08a8d860d5ad completed.
# Running Classifier
# Pipeline a18d7df5-9a99-4a55-8309-a888986952e8 completed.
# Running Classifier
# Pipeline 6cd37566-ae36-4cbc-b499-7bdf04fb6568 completed.
# Running Processor
# Running Classifier
# Pipeline e5c4094a-25c9-47c8-a08d-b8b3ac20bc2c completed.
# Running Classifier
# Pipeline 6749a5ae-ea1b-420f-b9ae-523e03af8673 completed.
# Running Classifier
# Pipeline 545471a2-eacf-4c69-b090-15c07a9ed4f6 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 845c91d9-f27e-4519-9563-03bbe2af6956 completed.
# Running Classifier
# Pipeline be89ca69-d6a6-4578-948a-6820d28e1cec completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline cba10c7a-88fd-4b9d-b68a-b109a9b3992f completed.
# Running Classifier
# Pipeline 5eaf2fde-c9a9-4627-b61a-d19a6a31b08f completed.
# Running Classifier
# Pipeline a3b03e8b-41e0-4ffa-ab24-2a3b52abe889 completed.
# Running Classifier
# Pipeline f3f04985-b5f9-4b9f-baa3-ee743df041c3 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 11022360-916b-4eb3-b2e5-a2161e11b5fd completed.
# Running Classifier
# Pipeline e7a1ebf9-0142-4f40-8b43-b0472a129779 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 406c03c7-d302-410e-8283-af494f73c8c0 completed.
# Running Classifier
# Pipeline 5f3709bc-06c8-48eb-86dc-43824b62182a completed.
# Running Classifier
# Pipeline 97cdc9c8-7dcd-4962-a3fc-8cf38035f37f completed.
# [{'pipeline_id': '1363a265-af89-4e38-8666-6544ef2e0efc',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '9f11dfb2-f4bd-49b7-b522-670c8d328057',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': '7d971f87-9809-4b12-b3f5-3268c70cf25d',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': '51bedc2a-1a48-4e57-8732-e52491be9839',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': '4e608e5f-3802-45c3-98ea-d2ac25035eb4',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '446c8109-1a06-4fb3-ab44-c2f3da89ae13',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': 'd4b789e0-6c0d-4bda-b1ad-b8ddbffefd22',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '08a8634e-d741-4f6e-8401-7bf62e0783dd',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '01d7fad6-1dd2-43bc-9c03-39033e21a83d',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_2',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': 'db7fe47d-fd06-4fd9-a998-b49b9b150a9c',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': 'f5b828f0-6ebd-44c0-9af0-718c7e4ff777',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '36d728ab-6e88-40cd-8cd0-4e978b254d0d',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': '6056c2d7-8285-4e6c-b7d8-b45057ce43f6',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '52d3e82b-2e27-4af8-a8fa-287b1b3669d0',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': 'fbb12f51-6335-48f6-8e67-4cac11a1bf03',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '6c7074e4-3dee-4748-bb6d-08a8d860d5ad',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_1',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': 'a18d7df5-9a99-4a55-8309-a888986952e8',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '6cd37566-ae36-4cbc-b499-7bdf04fb6568',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'e5c4094a-25c9-47c8-a08d-b8b3ac20bc2c',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': '6749a5ae-ea1b-420f-b9ae-523e03af8673',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '545471a2-eacf-4c69-b090-15c07a9ed4f6',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1']},
#  {'pipeline_id': '845c91d9-f27e-4519-9563-03bbe2af6956',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': 'be89ca69-d6a6-4578-948a-6820d28e1cec',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'cba10c7a-88fd-4b9d-b68a-b109a9b3992f',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_2',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': '5eaf2fde-c9a9-4627-b61a-d19a6a31b08f',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'a3b03e8b-41e0-4ffa-ab24-2a3b52abe889',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': 'f3f04985-b5f9-4b9f-baa3-ee743df041c3',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2']},
#  {'pipeline_id': '11022360-916b-4eb3-b2e5-a2161e11b5fd',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_1',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': 'e7a1ebf9-0142-4f40-8b43-b0472a129779',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '406c03c7-d302-410e-8283-af494f73c8c0',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': '5f3709bc-06c8-48eb-86dc-43824b62182a',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '97cdc9c8-7dcd-4962-a3fc-8cf38035f37f',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']}]

# %%
n = 4

repository = Repository(
    [(f"data_loader_{i}", DataLoader()) for i in range(n)] +
    [(f"processor_{i}", Processor()) for i in range(n)] +
    [(f"classifier_{i}", Classifier()) for i in range(n)] 
)

from time import time
start = time()
pipelines = repository.build_pipelines()
print(f"Built {len(pipelines)} pipelines in {time() - start:.2f} seconds")
# Out:
# Built 219200 pipelines in 3.39 seconds

# %%
pipeline = Pipeline([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline
# Out:
# Pipeline(id=d45a225f-eb32-4051-832f-f045d55b146d, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])

# %%
print(repository)
print(executor)
# Out:
# Repository(tasks=['data_loader_0', 'data_loader_1', 'data_loader_2', 'data_loader_3', 'processor_0', 'processor_1', 'processor_2', 'processor_3', 'classifier_0', 'classifier_1', 'classifier_2', 'classifier_3'], pipelines=219200)
# CachedExecutor(pipelines=32)

# %%
repository = Repository([
    ["data_loader", DataLoader()],
    ("processor_1", Processor()),
    ("pipeline", pipeline),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipelines = repository.build_pipelines()
for pipeline in pipelines:
    print(pipeline)

executor = CachedExecutor(pipelines, verbose=True)
executor.run()

executor.results
# Out:
# Pipeline(id=31104c11-d9c1-4bc7-bf2b-c200d00c0789, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=76212315-1fcf-46b5-b9cb-d01180ffc31e, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=8199dfda-8ede-4c16-8146-401b9742bdad, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=750af0d4-ff9b-4eaa-9b19-fd3821cca484, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=7f2fb841-c6c0-43c1-a308-a457ecd9b32a, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=e75c57f2-3773-405a-8aec-e8c5a4f5e905, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=e45ddb53-a0c4-42d5-b874-7872400c00e8, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=e6e57ea1-865b-4a46-99f7-5ebb93fe08dd, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=b59ef5e0-9c2c-4f3c-a25d-1d04537f9fba, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=1be3caf3-fc93-4125-81c3-68a0e686f06c, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Pipeline(id=165845a1-1e25-4689-94a9-29ee8724167c, tasks=['pipeline'])
# Pipeline(id=10e60083-e53f-4d33-822e-36d154eba872, tasks=['pipeline', 'processor_1', 'classifier_1'])
# Pipeline(id=737d1245-2e53-43b2-bba2-a875543b833e, tasks=['pipeline', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=03b60b08-a6c0-43e3-a606-608b2cda3a96, tasks=['pipeline', 'processor_1', 'classifier_2'])
# Pipeline(id=6efcdade-291a-439d-b3a2-a4a778b40488, tasks=['pipeline', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=9a4896e8-b341-4de4-a2bf-9ead74af4d2b, tasks=['pipeline', 'classifier_1'])
# Pipeline(id=2c6be6c7-67e5-4736-940b-9c9badfe6311, tasks=['pipeline', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=bccd1d37-9bee-40e7-9ea4-6fa63e53948c, tasks=['pipeline', 'classifier_1', 'classifier_2'])
# Pipeline(id=6afb7806-b389-4dd7-a95f-79b1c73967da, tasks=['pipeline', 'classifier_2'])
# Pipeline(id=0693e456-20cc-4f0a-b5ee-f2253ea14d3f, tasks=['pipeline', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=f2f95604-209a-498c-81d2-8b9f23ddbcc1, tasks=['pipeline', 'classifier_2', 'classifier_1'])
# Running DataLoader
# Running Processor
# Running Classifier
# Pipeline 31104c11-d9c1-4bc7-bf2b-c200d00c0789 completed.
# Running Classifier
# Pipeline 76212315-1fcf-46b5-b9cb-d01180ffc31e completed.
# Running Classifier
# Pipeline 8199dfda-8ede-4c16-8146-401b9742bdad completed.
# Running Classifier
# Pipeline 750af0d4-ff9b-4eaa-9b19-fd3821cca484 completed.
# Running Classifier
# Pipeline 7f2fb841-c6c0-43c1-a308-a457ecd9b32a completed.
# Running Processor
# Running Classifier
# Pipeline e75c57f2-3773-405a-8aec-e8c5a4f5e905 completed.
# Running Classifier
# Pipeline e45ddb53-a0c4-42d5-b874-7872400c00e8 completed.
# Running Classifier
# Pipeline e6e57ea1-865b-4a46-99f7-5ebb93fe08dd completed.
# Running Processor
# Running Classifier
# Pipeline b59ef5e0-9c2c-4f3c-a25d-1d04537f9fba completed.
# Running Classifier
# Pipeline 1be3caf3-fc93-4125-81c3-68a0e686f06c completed.
# Running DataLoader
# Running Processor
# Running Processor
# Running Classifier
# Running Classifier
# Pipeline 165845a1-1e25-4689-94a9-29ee8724167c completed.
# Running Processor
# Running Classifier
# Pipeline 10e60083-e53f-4d33-822e-36d154eba872 completed.
# Running Classifier
# Pipeline 737d1245-2e53-43b2-bba2-a875543b833e completed.
# Running Classifier
# Pipeline 03b60b08-a6c0-43e3-a606-608b2cda3a96 completed.
# Running Classifier
# Pipeline 6efcdade-291a-439d-b3a2-a4a778b40488 completed.
# Running Classifier
# Pipeline 9a4896e8-b341-4de4-a2bf-9ead74af4d2b completed.
# Running Processor
# Running Classifier
# Pipeline 2c6be6c7-67e5-4736-940b-9c9badfe6311 completed.
# Running Classifier
# Pipeline bccd1d37-9bee-40e7-9ea4-6fa63e53948c completed.
# Running Classifier
# Pipeline 6afb7806-b389-4dd7-a95f-79b1c73967da completed.
# Running Processor
# Running Classifier
# Pipeline 0693e456-20cc-4f0a-b5ee-f2253ea14d3f completed.
# Running Classifier
# Pipeline f2f95604-209a-498c-81d2-8b9f23ddbcc1 completed.
# [{'pipeline_id': '31104c11-d9c1-4bc7-bf2b-c200d00c0789',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '76212315-1fcf-46b5-b9cb-d01180ffc31e',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '8199dfda-8ede-4c16-8146-401b9742bdad',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '750af0d4-ff9b-4eaa-9b19-fd3821cca484',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '7f2fb841-c6c0-43c1-a308-a457ecd9b32a',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1']},
#  {'pipeline_id': 'e75c57f2-3773-405a-8aec-e8c5a4f5e905',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'e45ddb53-a0c4-42d5-b874-7872400c00e8',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': 'e6e57ea1-865b-4a46-99f7-5ebb93fe08dd',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2']},
#  {'pipeline_id': 'b59ef5e0-9c2c-4f3c-a25d-1d04537f9fba',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '1be3caf3-fc93-4125-81c3-68a0e686f06c',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '165845a1-1e25-4689-94a9-29ee8724167c',
#   'output': 'output',
#   'tasks': ['pipeline']},
#  {'pipeline_id': '10e60083-e53f-4d33-822e-36d154eba872',
#   'output': 'output',
#   'tasks': ['pipeline', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '737d1245-2e53-43b2-bba2-a875543b833e',
#   'output': 'output',
#   'tasks': ['pipeline', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '03b60b08-a6c0-43e3-a606-608b2cda3a96',
#   'output': 'output',
#   'tasks': ['pipeline', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '6efcdade-291a-439d-b3a2-a4a778b40488',
#   'output': 'output',
#   'tasks': ['pipeline', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '9a4896e8-b341-4de4-a2bf-9ead74af4d2b',
#   'output': 'output',
#   'tasks': ['pipeline', 'classifier_1']},
#  {'pipeline_id': '2c6be6c7-67e5-4736-940b-9c9badfe6311',
#   'output': 'output',
#   'tasks': ['pipeline', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'bccd1d37-9bee-40e7-9ea4-6fa63e53948c',
#   'output': 'output',
#   'tasks': ['pipeline', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '6afb7806-b389-4dd7-a95f-79b1c73967da',
#   'output': 'output',
#   'tasks': ['pipeline', 'classifier_2']},
#  {'pipeline_id': '0693e456-20cc-4f0a-b5ee-f2253ea14d3f',
#   'output': 'output',
#   'tasks': ['pipeline', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'f2f95604-209a-498c-81d2-8b9f23ddbcc1',
#   'output': 'output',
#   'tasks': ['pipeline', 'classifier_2', 'classifier_1']}]
