# %%
from pypekit import Task, Repository, CachedExecutor

class DataLoader(Task):
    input_types = ["source"]
    output_types = ["raw"]

    def run(self, input_path, output_path):
        print(f"Running DataLoader")
        return "output_path"

class Processor(Task):
    input_types = ["raw", "processed"]
    output_types = ["processed"]
        
    def run(self, input_path, output_path):
        print(f"Running Processor")
        return "output_path"

class Classifier(Task):
    input_types = ["raw", "processed"]
    output_types = ["sink", "processed"]
        
    def run(self, input_path, output_path):
        print(f"Running Classifier")
        return "output_path"
    
repository = Repository([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipelines = repository.build_pipelines()
for pipeline in pipelines:
    print(pipeline)

executor = CachedExecutor(".", pipelines, verbose=True)
executor.run()

executor.results
# Out:
# Pipeline(id=7fdae6ff-8f1a-4671-bf07-45ebc0861e31, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=cd8cec42-ac36-4c18-ab10-5a1bc53e0737, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=a97e4085-81c5-44e4-8c6a-30d5a8f5e204, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=0a0bcbbd-95c8-4591-82bd-cb90b6112a29, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=14eff1b7-8931-4717-9e9c-48d5185980aa, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=4fdce5b0-86e6-4356-9111-483c640e1e84, tasks=['data_loader', 'processor_1', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=d0a412ed-5604-44ba-9373-0c2365d2a9f4, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=584decd0-1633-4217-8c66-bf0610e9e7dc, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=7b068ef0-fdec-4e3a-bcae-5a6f0867e30c, tasks=['data_loader', 'processor_1', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=44a1ea01-8444-4627-b093-2f4ea069f834, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=a453c6b1-b3c3-4ada-a05e-d17413a802b3, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=b7731324-1df0-43de-b554-4633c5d59f23, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=5ca07cba-d201-4841-843d-19025b17bfce, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=27ed1067-134e-4cef-ad0a-911a46f520a6, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=b54e79ca-737f-46a8-8943-433e1079ffec, tasks=['data_loader', 'processor_2', 'classifier_1'])
# Pipeline(id=b2e1ae8e-8986-4c98-8c8a-38dda7bb8574, tasks=['data_loader', 'processor_2', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=96c51a6c-ce09-4b28-8970-8c3c41c4d8ba, tasks=['data_loader', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=773a8687-1899-446f-9b46-5608b23efd9a, tasks=['data_loader', 'processor_2', 'classifier_2'])
# Pipeline(id=e09be29e-32e7-48bc-82f3-f26b5a728df9, tasks=['data_loader', 'processor_2', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=ef19db31-3862-458b-a605-f09b9f3ca6a5, tasks=['data_loader', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=7a82ac8d-16f6-42a5-9ed1-e4d240e23e30, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=12e5eedf-00b6-4908-bd03-04796335df90, tasks=['data_loader', 'classifier_1', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=419b399f-c6ab-4f53-b45b-1b07fbfe892d, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=4792cb7c-b28c-49c0-bff1-1a1ffc081bd6, tasks=['data_loader', 'classifier_1', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=f6497136-cf31-4c09-9dab-259ae5dc6ca1, tasks=['data_loader', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=48eed8d9-d56d-49ff-88e2-6a4b36fdaa41, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=49daee75-3905-4d60-9687-c05f9e5dc91b, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=0618ec3f-8513-4475-ab84-0ed26ae002f2, tasks=['data_loader', 'classifier_2', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=e9e2436a-e884-4571-a9e5-da73151dd935, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=d910aa1b-f023-4ce8-bb3a-a0880d351c23, tasks=['data_loader', 'classifier_2', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=645cdc38-7fdd-474a-8ea4-3643b66189fb, tasks=['data_loader', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=d0f77b5e-838d-49b1-9114-2ff411d29e8b, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Running ExampleTask
# Running ExampleTask2
# Running ExampleTask2
# Running ExampleTask3
# Pipeline 7fdae6ff-8f1a-4671-bf07-45ebc0861e31 completed.
# Running ExampleTask3
# Pipeline cd8cec42-ac36-4c18-ab10-5a1bc53e0737 completed.
# Running ExampleTask3
# Pipeline a97e4085-81c5-44e4-8c6a-30d5a8f5e204 completed.
# Running ExampleTask3
# Pipeline 0a0bcbbd-95c8-4591-82bd-cb90b6112a29 completed.
# Running ExampleTask3
# Pipeline 14eff1b7-8931-4717-9e9c-48d5185980aa completed.
# Running ExampleTask2
# Running ExampleTask3
# Pipeline 4fdce5b0-86e6-4356-9111-483c640e1e84 completed.
# Running ExampleTask3
# Pipeline d0a412ed-5604-44ba-9373-0c2365d2a9f4 completed.
# Running ExampleTask3
# Pipeline 584decd0-1633-4217-8c66-bf0610e9e7dc completed.
# Running ExampleTask2
# Running ExampleTask3
# Pipeline 7b068ef0-fdec-4e3a-bcae-5a6f0867e30c completed.
# Running ExampleTask3
# Pipeline 44a1ea01-8444-4627-b093-2f4ea069f834 completed.
# Running ExampleTask2
# Running ExampleTask2
# Running ExampleTask3
# Pipeline a453c6b1-b3c3-4ada-a05e-d17413a802b3 completed.
# Running ExampleTask3
# Pipeline b7731324-1df0-43de-b554-4633c5d59f23 completed.
# Running ExampleTask3
# Pipeline 5ca07cba-d201-4841-843d-19025b17bfce completed.
# Running ExampleTask3
# Pipeline 27ed1067-134e-4cef-ad0a-911a46f520a6 completed.
# Running ExampleTask3
# Pipeline b54e79ca-737f-46a8-8943-433e1079ffec completed.
# Running ExampleTask2
# Running ExampleTask3
# Pipeline b2e1ae8e-8986-4c98-8c8a-38dda7bb8574 completed.
# Running ExampleTask3
# Pipeline 96c51a6c-ce09-4b28-8970-8c3c41c4d8ba completed.
# Running ExampleTask3
# Pipeline 773a8687-1899-446f-9b46-5608b23efd9a completed.
# Running ExampleTask2
# Running ExampleTask3
# Pipeline e09be29e-32e7-48bc-82f3-f26b5a728df9 completed.
# Running ExampleTask3
# Pipeline ef19db31-3862-458b-a605-f09b9f3ca6a5 completed.
# Running ExampleTask3
# Pipeline 7a82ac8d-16f6-42a5-9ed1-e4d240e23e30 completed.
# Running ExampleTask2
# Running ExampleTask2
# Running ExampleTask3
# Pipeline 12e5eedf-00b6-4908-bd03-04796335df90 completed.
# Running ExampleTask3
# Pipeline 419b399f-c6ab-4f53-b45b-1b07fbfe892d completed.
# Running ExampleTask2
# Running ExampleTask2
# Running ExampleTask3
# Pipeline 4792cb7c-b28c-49c0-bff1-1a1ffc081bd6 completed.
# Running ExampleTask3
# Pipeline f6497136-cf31-4c09-9dab-259ae5dc6ca1 completed.
# Running ExampleTask3
# Pipeline 48eed8d9-d56d-49ff-88e2-6a4b36fdaa41 completed.
# Running ExampleTask3
# Pipeline 49daee75-3905-4d60-9687-c05f9e5dc91b completed.
# Running ExampleTask2
# Running ExampleTask2
# Running ExampleTask3
# Pipeline 0618ec3f-8513-4475-ab84-0ed26ae002f2 completed.
# Running ExampleTask3
# Pipeline e9e2436a-e884-4571-a9e5-da73151dd935 completed.
# Running ExampleTask2
# Running ExampleTask2
# Running ExampleTask3
# Pipeline d910aa1b-f023-4ce8-bb3a-a0880d351c23 completed.
# Running ExampleTask3
# Pipeline 645cdc38-7fdd-474a-8ea4-3643b66189fb completed.
# Running ExampleTask3
# Pipeline d0f77b5e-838d-49b1-9114-2ff411d29e8b completed.
# [{'pipeline_id': '7fdae6ff-8f1a-4671-bf07-45ebc0861e31',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_1']},
#  {'pipeline_id': 'cd8cec42-ac36-4c18-ab10-5a1bc53e0737',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': 'a97e4085-81c5-44e4-8c6a-30d5a8f5e204',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': '0a0bcbbd-95c8-4591-82bd-cb90b6112a29',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': '14eff1b7-8931-4717-9e9c-48d5185980aa',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '4fdce5b0-86e6-4356-9111-483c640e1e84',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': 'd0a412ed-5604-44ba-9373-0c2365d2a9f4',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '584decd0-1633-4217-8c66-bf0610e9e7dc',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '7b068ef0-fdec-4e3a-bcae-5a6f0867e30c',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_2',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': '44a1ea01-8444-4627-b093-2f4ea069f834',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': 'a453c6b1-b3c3-4ada-a05e-d17413a802b3',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'b7731324-1df0-43de-b554-4633c5d59f23',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': '5ca07cba-d201-4841-843d-19025b17bfce',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '27ed1067-134e-4cef-ad0a-911a46f520a6',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': 'b54e79ca-737f-46a8-8943-433e1079ffec',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1']},
#  {'pipeline_id': 'b2e1ae8e-8986-4c98-8c8a-38dda7bb8574',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_1',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': '96c51a6c-ce09-4b28-8970-8c3c41c4d8ba',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '773a8687-1899-446f-9b46-5608b23efd9a',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'e09be29e-32e7-48bc-82f3-f26b5a728df9',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': 'ef19db31-3862-458b-a605-f09b9f3ca6a5',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '7a82ac8d-16f6-42a5-9ed1-e4d240e23e30',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_1']},
#  {'pipeline_id': '12e5eedf-00b6-4908-bd03-04796335df90',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': '419b399f-c6ab-4f53-b45b-1b07fbfe892d',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '4792cb7c-b28c-49c0-bff1-1a1ffc081bd6',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_2',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': 'f6497136-cf31-4c09-9dab-259ae5dc6ca1',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': '48eed8d9-d56d-49ff-88e2-6a4b36fdaa41',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '49daee75-3905-4d60-9687-c05f9e5dc91b',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_2']},
#  {'pipeline_id': '0618ec3f-8513-4475-ab84-0ed26ae002f2',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_1',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': 'e9e2436a-e884-4571-a9e5-da73151dd935',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'd910aa1b-f023-4ce8-bb3a-a0880d351c23',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': '645cdc38-7fdd-474a-8ea4-3643b66189fb',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_2', 'processor_2', 'classifier_1']},
#  {'pipeline_id': 'd0f77b5e-838d-49b1-9114-2ff411d29e8b',
#   'output_path': 'output path 3',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']}]

# %%
n = 4

repository = Repository(
    [(f"data_loader_{i}", DataLoader()) for i in range(n)] +
    [(f"processor_{i}", Processor()) for i in range(n)] +
    [(f"classifier_{i}", Classifier()) for i in range(n)] 
)

from time import time
start = time()
pipelines = repository.build_pipelines()
print(f"Built {len(pipelines)} pipelines in {time() - start:.2f} seconds")
# Out:
# Built 219200 pipelines in 5.17 seconds
