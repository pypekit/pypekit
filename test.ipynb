completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 46c8c75f-2a26-4913-badd-b7db4c3fce2f completed.
# Running Classifier
# Pipeline 05fd3699-8965-4218-8109-9942dc4c093a completed.
# Running Classifier
# Pipeline 6d550e4e-bffa-4604-8665-8a91b33fa33f completed.
# Running Classifier
# Pipeline daffa0b9-ebdd-4c77-b676-4195a2ab0153 completed.
# Running Classifier
# Pipeline 5dac8056-b628-41e1-aed4-fa4097caf0c6 completed.
# Running Processor
# Running Classifier
# Pipeline 6af0ab38-d0b8-46ce-b83d-cfe025668bd7 completed.
# Running Classifier
# Pipeline 3b4d621e-6e93-4aa5-ade7-705d6a90ab3c completed.
# Running Classifier
# Pipeline 479b8f16-b07e-4fa8-a6a8-fbdc33d87a7b completed.
# Running Processor
# Running Classifier
# Pipeline fadbbafd-ee27-4193-8968-1c0ea7eb1c95 completed.
# Running Classifier
# Pipeline 4c0a90c0-9f5c-4b65-9bb5-2637297d5887 completed.
# Running Classifier
# Pipeline 3250990b-a7ec-43fe-8b91-4d4c2fb2e1e5 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline c21a09a4-0ca7-4080-a31d-b62d134e8fda completed.
# Running Classifier
# Pipeline 3252354e-7694-4750-b860-242702589dab completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline bce8bed1-342b-4980-8a14-589c13fc61ba completed.
# Running Classifier
# Pipeline 3c0c00e1-6e3e-4aa9-a1da-855bac8faa35 completed.
# Running Classifier
# Pipeline 89d28799-dc07-45d3-a563-8f7c152790f4 completed.
# Running Classifier
# Pipeline 11894943-10fa-468c-a654-6256c7df828d completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 5fad6cab-182e-4b8f-9a39-b910a85cda94 completed.
# Running Classifier
# Pipeline 54b266ca-3768-4ff2-a531-f27cc4d7b7da completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 88f52efa-6ad5-4086-866e-048528a8c9a5 completed.
# Running Classifier
# Pipeline f1e0481d-a540-4787-9e0e-e7a6e3e31e56 completed.
# Running Classifier
# Pipeline 2f5c93b3-cf14-49d2-a2f3-5953d78c79cd completed.
# [{'pipeline_id': 'e83d15c1-1c29-4181-a9f6-d6c866a9cdfb',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_1']},
#  {'pipeline_id': 'ea96d232-24e7-47b7-aec8-1ee3a8af52cb',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': 'b8080844-a119-47c7-8413-e0c6e61d0ccc',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'eb360f32-bfd6-4d81-bcee-918a6fb62d0c',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': '3503077b-eb82-49ee-9791-35e55aba96fc',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'fdd1ec41-df0c-4beb-a7df-6e1278912281',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': '49dd446d-04f9-402b-b8fb-cc7a77ae4b47',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': 'ba51e5c9-b335-432e-8f69-a09dc4ee11a7',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '30a6d028-2361-492b-9e16-32fb43ad8c9f',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_2',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': '240988f3-2b01-44a2-a0c6-e4223f8d2a56',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '46c8c75f-2a26-4913-badd-b7db4c3fce2f',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '05fd3699-8965-4218-8109-9942dc4c093a',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': '6d550e4e-bffa-4604-8665-8a91b33fa33f',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'daffa0b9-ebdd-4c77-b676-4195a2ab0153',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': '5dac8056-b628-41e1-aed4-fa4097caf0c6',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '6af0ab38-d0b8-46ce-b83d-cfe025668bd7',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_1',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': '3b4d621e-6e93-4aa5-ade7-705d6a90ab3c',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '479b8f16-b07e-4fa8-a6a8-fbdc33d87a7b',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'fadbbafd-ee27-4193-8968-1c0ea7eb1c95',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': '4c0a90c0-9f5c-4b65-9bb5-2637297d5887',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '3250990b-a7ec-43fe-8b91-4d4c2fb2e1e5',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1']},
#  {'pipeline_id': 'c21a09a4-0ca7-4080-a31d-b62d134e8fda',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': '3252354e-7694-4750-b860-242702589dab',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'bce8bed1-342b-4980-8a14-589c13fc61ba',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_2',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': '3c0c00e1-6e3e-4aa9-a1da-855bac8faa35',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': '89d28799-dc07-45d3-a563-8f7c152790f4',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '11894943-10fa-468c-a654-6256c7df828d',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2']},
#  {'pipeline_id': '5fad6cab-182e-4b8f-9a39-b910a85cda94',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_1',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': '54b266ca-3768-4ff2-a531-f27cc4d7b7da',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '88f52efa-6ad5-4086-866e-048528a8c9a5',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': 'f1e0481d-a540-4787-9e0e-e7a6e3e31e56',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '2f5c93b3-cf14-49d2-a2f3-5953d78c79cd',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']}]

# %%
n = 4

repository = Repository(
    [(f"data_loader_{i}", DataLoader()) for i in range(n)] +
    [(f"processor_{i}", Processor()) for i in range(n)] +
    [(f"classifier_{i}", Classifier()) for i in range(n)] 
)

from time import time
start = time()
pipelines = repository.build_pipelines()
print(f"Built {len(pipelines)} pipelines in {time() - start:.2f} seconds")
# Out:
# Built 219200 pipelines in 2.40 seconds

# %%
pipeline = Pipeline([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline
# Out:
# Pipeline(id=765f3bd4-b9ea-4f8c-bd2a-c4d806bfa955, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])

# %%
print(repository)
print(executor)
# Out:
# Repository(tasks=['data_loader_0', 'data_loader_1', 'data_loader_2', 'data_loader_3', 'processor_0', 'processor_1', 'processor_2', 'processor_3', 'classifier_0', 'classifier_1', 'classifier_2', 'classifier_3'], pipelines=219200)
# CachedExecutor(cache_dir=cache, pipelines=32)

# %%
repository = Repository([
    ["data_loader", DataLoader()],
    ("processor_1", Processor()),
    ("pipeline", pipeline),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipelines = repository.build_pipelines()
for pipeline in pipelines:
    print(pipeline)

executor = CachedExecutor(pipelines, verbose=True)
executor.run()

executor.results
# Out:
# Pipeline(id=b2b268f5-837c-4e8f-9ec3-9bbb91652354, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=129f0944-eba9-43a5-a732-19a5241f3b21, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=d5257e4e-4e66-4585-a6d8-1fa6ce469632, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=a3906828-696f-4162-a505-8fc86dd79399, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=378cb42a-c06d-464b-980c-d267fa4fc6bf, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=cc9d7bb4-6d3b-4c27-8e35-ce2cae6f91e5, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=2394bd45-b103-4fa0-afcd-55d2cb8d5aa3, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=fbaac1ed-46e9-47a7-94e8-30e5f0bf5948, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=01a37221-5008-4d8b-8271-956aa49040c5, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=a47682ed-4372-42f3-a3b3-7ceaaad0748d, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Pipeline(id=0759d0aa-344c-4ddf-b21c-0d9a1f805071, tasks=['pipeline'])
# Pipeline(id=6d977191-3680-425e-936e-7505bad13c4b, tasks=['pipeline', 'processor_1', 'classifier_1'])
# Pipeline(id=90e1bd45-b98c-4c14-be78-6bde7fdc5c3a, tasks=['pipeline', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=9c877c6f-b484-43f0-902b-13126a5c04f4, tasks=['pipeline', 'processor_1', 'classifier_2'])
# Pipeline(id=23332097-7f68-48b7-9892-0fd8e9d75dc4, tasks=['pipeline', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=85b58697-8e36-458a-b2cb-cd133489ee80, tasks=['pipeline', 'classifier_1'])
# Pipeline(id=df61533b-2b9e-403b-aa97-8e810ca96fd8, tasks=['pipeline', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=fb42fdbc-8cc6-4983-803b-8cf8f8e7a67a, tasks=['pipeline', 'classifier_1', 'classifier_2'])
# Pipeline(id=8316879e-958d-427a-aa5d-4c62cdab837d, tasks=['pipeline', 'classifier_2'])
# Pipeline(id=bb6d1c4f-251a-4839-88df-fe9b8b2f29e7, tasks=['pipeline', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=7bc987cd-9faa-4f7a-8335-f32250d61654, tasks=['pipeline', 'classifier_2', 'classifier_1'])
# Running DataLoader
# Running Processor
# Running Classifier
# Pipeline b2b268f5-837c-4e8f-9ec3-9bbb91652354 completed.
# Running Classifier
# Pipeline 129f0944-eba9-43a5-a732-19a5241f3b21 completed.
# Running Classifier
# Pipeline d5257e4e-4e66-4585-a6d8-1fa6ce469632 completed.
# Running Classifier
# Pipeline a3906828-696f-4162-a505-8fc86dd79399 completed.
# Running Classifier
# Pipeline 378cb42a-c06d-464b-980c-d267fa4fc6bf completed.
# Running Processor
# Running Classifier
# Pipeline cc9d7bb4-6d3b-4c27-8e35-ce2cae6f91e5 completed.
# Running Classifier
# Pipeline 2394bd45-b103-4fa0-afcd-55d2cb8d5aa3 completed.
# Running Classifier
# Pipeline fbaac1ed-46e9-47a7-94e8-30e5f0bf5948 completed.
# Running Processor
# Running Classifier
# Pipeline 01a37221-5008-4d8b-8271-956aa49040c5 completed.
# Running Classifier
# Pipeline a47682ed-4372-42f3-a3b3-7ceaaad0748d completed.
# Running DataLoader
# Running Processor
# Running Processor
# Running Classifier
# Running Classifier
# Running Classifier
# Running Classifier
# Running Classifier
# Running Classifier
# Running Classifier
# Running Classifier
# Pipeline 0759d0aa-344c-4ddf-b21c-0d9a1f805071 completed.
# Running Processor
# Running Classifier
# Pipeline 6d977191-3680-425e-936e-7505bad13c4b completed.
# Running Classifier
# Pipeline 90e1bd45-b98c-4c14-be78-6bde7fdc5c3a completed.
# Running Classifier
# Pipeline 9c877c6f-b484-43f0-902b-13126a5c04f4 completed.
# Running Classifier
# Pipeline 23332097-7f68-48b7-9892-0fd8e9d75dc4 completed.
# Running Classifier
# Pipeline 85b58697-8e36-458a-b2cb-cd133489ee80 completed.
# Running Processor
# Running Classifier
# Pipeline df61533b-2b9e-403b-aa97-8e810ca96fd8 completed.
# Running Classifier
# Pipeline fb42fdbc-8cc6-4983-803b-8cf8f8e7a67a completed.
# Running Classifier
# Pipeline 8316879e-958d-427a-aa5d-4c62cdab837d completed.
# Running Processor
# Running Classifier
# Pipeline bb6d1c4f-251a-4839-88df-fe9b8b2f29e7 completed.
# Running Classifier
# Pipeline 7bc987cd-9faa-4f7a-8335-f32250d61654 completed.
# [{'pipeline_id': 'b2b268f5-837c-4e8f-9ec3-9bbb91652354',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '129f0944-eba9-43a5-a732-19a5241f3b21',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': 'd5257e4e-4e66-4585-a6d8-1fa6ce469632',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'a3906828-696f-4162-a505-8fc86dd79399',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '378cb42a-c06d-464b-980c-d267fa4fc6bf',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1']},
#  {'pipeline_id': 'cc9d7bb4-6d3b-4c27-8e35-ce2cae6f91e5',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '2394bd45-b103-4fa0-afcd-55d2cb8d5aa3',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': 'fbaac1ed-46e9-47a7-94e8-30e5f0bf5948',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2']},
#  {'pipeline_id': '01a37221-5008-4d8b-8271-956aa49040c5',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'a47682ed-4372-42f3-a3b3-7ceaaad0748d',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '0759d0aa-344c-4ddf-b21c-0d9a1f805071',
#   'output_path': 'output_path',
#   'tasks': ['pipeline']},
#  {'pipeline_id': '6d977191-3680-425e-936e-7505bad13c4b',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '90e1bd45-b98c-4c14-be78-6bde7fdc5c3a',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '9c877c6f-b484-43f0-902b-13126a5c04f4',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '23332097-7f68-48b7-9892-0fd8e9d75dc4',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '85b58697-8e36-458a-b2cb-cd133489ee80',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'classifier_1']},
#  {'pipeline_id': 'df61533b-2b9e-403b-aa97-8e810ca96fd8',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': 'fb42fdbc-8cc6-4983-803b-8cf8f8e7a67a',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '8316879e-958d-427a-aa5d-4c62cdab837d',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'classifier_2']},
#  {'pipeline_id': 'bb6d1c4f-251a-4839-88df-fe9b8b2f29e7',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '7bc987cd-9faa-4f7a-8335-f32250d61654',
#   'output_path': 'output_path',
#   'tasks': ['pipeline', 'classifier_2', 'classifier_1']}]
