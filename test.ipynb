# %%
from pypekit import Task, Repository, CachedExecutor

class DataLoader(Task):
    input_types = ["source"]
    output_types = ["raw"]

    def run(self, input_path, output_path):
        print(f"Running DataLoader")
        return "output_path"

class Processor(Task):
    input_types = ["raw", "processed"]
    output_types = ["processed"]
        
    def run(self, input_path, output_path):
        print(f"Running Processor")
        return "output_path"

class Classifier(Task):
    input_types = ["raw", "processed"]
    output_types = ["sink", "processed"]
        
    def run(self, input_path, output_path):
        print(f"Running Classifier")
        return "output_path"
    
repository = Repository([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipelines = repository.build_pipelines()
for pipeline in pipelines:
    print(pipeline)

executor = CachedExecutor(pipelines, verbose=True)
executor.run()

executor.results
# Out:
# Pipeline(id=20ee8d58-3ee4-4990-96fe-bd2401b7f8bc, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=8938f753-f542-49c8-aa21-488fba757994, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=fa5364e1-1021-4e1e-bfe1-cac49da3d62f, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=f7442521-5d40-4a09-9ea1-e187bd414d1f, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=3fbb4424-82ed-42dd-8e71-3ce54dff538a, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=fc860626-c9cd-4387-b4b6-97b0e12f9bcd, tasks=['data_loader', 'processor_1', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=351e7185-7b42-4f26-9bfd-d828e9eb879a, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=d369a702-3684-4814-99e7-1ebf0e40c6ff, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=959e5fbf-5577-4392-a062-6b8b8a8c65bb, tasks=['data_loader', 'processor_1', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=8e898d38-b7da-46e8-8514-4397d4732924, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=86f756d9-db60-4cbf-838c-58d15a9b1dcb, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=36ff912e-0a9b-44a3-b689-ac0336c89e1b, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=995bebdf-1eea-435c-806d-eee1be9ea5c8, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=1e18cff5-8932-4bb8-896a-c84c3ed8546a, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=ec9dc040-502c-4624-8002-05f60c5d2e34, tasks=['data_loader', 'processor_2', 'classifier_1'])
# Pipeline(id=0d71f366-0bf4-49c4-a526-25fc8aabe5ed, tasks=['data_loader', 'processor_2', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=a57001d6-e37e-4fab-b530-f15e7a90e2ff, tasks=['data_loader', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=398e01e2-27c1-43af-b12d-4a2dfb0aef67, tasks=['data_loader', 'processor_2', 'classifier_2'])
# Pipeline(id=f48bf10d-7711-4ac9-a54c-d0bad01982f7, tasks=['data_loader', 'processor_2', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=40a92982-698b-4963-b1da-35edfeecc728, tasks=['data_loader', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=22fac14e-abb9-4231-a451-7c7a9521a9fa, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=165275fd-7bc2-474c-8b9b-f80d6cf40003, tasks=['data_loader', 'classifier_1', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=12c21411-5db9-4489-8e55-39533d8d8bf9, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=6d9c37f8-0700-49d3-ab82-7964ca78cabb, tasks=['data_loader', 'classifier_1', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=4fb015df-36da-4e5e-8b90-6715d59bb083, tasks=['data_loader', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=a478149b-9330-4944-be4c-3c1cef4b0a01, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=6bf984aa-38de-42f2-8897-c368e1bc7b46, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=ca04ec60-3887-4ec0-8801-a489edc3bdec, tasks=['data_loader', 'classifier_2', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=3413dc84-dcd5-4bd6-98ea-d2dbe169691a, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=cb7707ef-86cb-4f20-9a24-295084dab66b, tasks=['data_loader', 'classifier_2', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=e167782a-01e2-4a3b-8fd6-fde97653e2e2, tasks=['data_loader', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=9564ccf2-6fa5-4a9c-9ba5-f58c664c9edd, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Running DataLoader
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 20ee8d58-3ee4-4990-96fe-bd2401b7f8bc completed.
# Running Classifier
# Pipeline 8938f753-f542-49c8-aa21-488fba757994 completed.
# Running Classifier
# Pipeline fa5364e1-1021-4e1e-bfe1-cac49da3d62f completed.
# Running Classifier
# Pipeline f7442521-5d40-4a09-9ea1-e187bd414d1f completed.
# Running Classifier
# Pipeline 3fbb4424-82ed-42dd-8e71-3ce54dff538a completed.
# Running Processor
# Running Classifier
# Pipeline fc860626-c9cd-4387-b4b6-97b0e12f9bcd completed.
# Running Classifier
# Pipeline 351e7185-7b42-4f26-9bfd-d828e9eb879a completed.
# Running Classifier
# Pipeline d369a702-3684-4814-99e7-1ebf0e40c6ff completed.
# Running Processor
# Running Classifier
# Pipeline 959e5fbf-5577-4392-a062-6b8b8a8c65bb completed.
# Running Classifier
# Pipeline 8e898d38-b7da-46e8-8514-4397d4732924 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 86f756d9-db60-4cbf-838c-58d15a9b1dcb completed.
# Running Classifier
# Pipeline 36ff912e-0a9b-44a3-b689-ac0336c89e1b completed.
# Running Classifier
# Pipeline 995bebdf-1eea-435c-806d-eee1be9ea5c8 completed.
# Running Classifier
# Pipeline 1e18cff5-8932-4bb8-896a-c84c3ed8546a completed.
# Running Classifier
# Pipeline ec9dc040-502c-4624-8002-05f60c5d2e34 completed.
# Running Processor
# Running Classifier
# Pipeline 0d71f366-0bf4-49c4-a526-25fc8aabe5ed completed.
# Running Classifier
# Pipeline a57001d6-e37e-4fab-b530-f15e7a90e2ff completed.
# Running Classifier
# Pipeline 398e01e2-27c1-43af-b12d-4a2dfb0aef67 completed.
# Running Processor
# Running Classifier
# Pipeline f48bf10d-7711-4ac9-a54c-d0bad01982f7 completed.
# Running Classifier
# Pipeline 40a92982-698b-4963-b1da-35edfeecc728 completed.
# Running Classifier
# Pipeline 22fac14e-abb9-4231-a451-7c7a9521a9fa completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 165275fd-7bc2-474c-8b9b-f80d6cf40003 completed.
# Running Classifier
# Pipeline 12c21411-5db9-4489-8e55-39533d8d8bf9 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 6d9c37f8-0700-49d3-ab82-7964ca78cabb completed.
# Running Classifier
# Pipeline 4fb015df-36da-4e5e-8b90-6715d59bb083 completed.
# Running Classifier
# Pipeline a478149b-9330-4944-be4c-3c1cef4b0a01 completed.
# Running Classifier
# Pipeline 6bf984aa-38de-42f2-8897-c368e1bc7b46 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline ca04ec60-3887-4ec0-8801-a489edc3bdec completed.
# Running Classifier
# Pipeline 3413dc84-dcd5-4bd6-98ea-d2dbe169691a completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline cb7707ef-86cb-4f20-9a24-295084dab66b completed.
# Running Classifier
# Pipeline e167782a-01e2-4a3b-8fd6-fde97653e2e2 completed.
# Running Classifier
# Pipeline 9564ccf2-6fa5-4a9c-9ba5-f58c664c9edd completed.
# [{'pipeline_id': '20ee8d58-3ee4-4990-96fe-bd2401b7f8bc',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '8938f753-f542-49c8-aa21-488fba757994',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': 'fa5364e1-1021-4e1e-bfe1-cac49da3d62f',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'f7442521-5d40-4a09-9ea1-e187bd414d1f',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': '3fbb4424-82ed-42dd-8e71-3ce54dff538a',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'fc860626-c9cd-4387-b4b6-97b0e12f9bcd',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': '351e7185-7b42-4f26-9bfd-d828e9eb879a',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': 'd369a702-3684-4814-99e7-1ebf0e40c6ff',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '959e5fbf-5577-4392-a062-6b8b8a8c65bb',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_2',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': '8e898d38-b7da-46e8-8514-4397d4732924',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '86f756d9-db60-4cbf-838c-58d15a9b1dcb',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': '36ff912e-0a9b-44a3-b689-ac0336c89e1b',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_1',
#    'classifier_2']},
#  {'pipeline_id': '995bebdf-1eea-435c-806d-eee1be9ea5c8',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '1e18cff5-8932-4bb8-896a-c84c3ed8546a',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_2',
#    'classifier_1']},
#  {'pipeline_id': 'ec9dc040-502c-4624-8002-05f60c5d2e34',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '0d71f366-0bf4-49c4-a526-25fc8aabe5ed',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_1',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': 'a57001d6-e37e-4fab-b530-f15e7a90e2ff',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '398e01e2-27c1-43af-b12d-4a2dfb0aef67',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'f48bf10d-7711-4ac9-a54c-d0bad01982f7',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': '40a92982-698b-4963-b1da-35edfeecc728',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2', 'classifier_1']},
#  {'pipeline_id': '22fac14e-abb9-4231-a451-7c7a9521a9fa',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1']},
#  {'pipeline_id': '165275fd-7bc2-474c-8b9b-f80d6cf40003',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_1',
#    'processor_2',
#    'classifier_2']},
#  {'pipeline_id': '12c21411-5db9-4489-8e55-39533d8d8bf9',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  {'pipeline_id': '6d9c37f8-0700-49d3-ab82-7964ca78cabb',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_2',
#    'processor_1',
#    'classifier_2']},
#  {'pipeline_id': '4fb015df-36da-4e5e-8b90-6715d59bb083',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'processor_2', 'classifier_2']},
#  {'pipeline_id': 'a478149b-9330-4944-be4c-3c1cef4b0a01',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  {'pipeline_id': '6bf984aa-38de-42f2-8897-c368e1bc7b46',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2']},
#  {'pipeline_id': 'ca04ec60-3887-4ec0-8801-a489edc3bdec',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_1',
#    'processor_2',
#    'classifier_1']},
#  {'pipeline_id': '3413dc84-dcd5-4bd6-98ea-d2dbe169691a',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  {'pipeline_id': 'cb7707ef-86cb-4f20-9a24-295084dab66b',
#   'output_path': 'output_path',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_2',
#    'processor_1',
#    'classifier_1']},
#  {'pipeline_id': 'e167782a-01e2-4a3b-8fd6-fde97653e2e2',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'processor_2', 'classifier_1']},
#  {'pipeline_id': '9564ccf2-6fa5-4a9c-9ba5-f58c664c9edd',
#   'output_path': 'output_path',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']}]

# %%
n = 4

repository = Repository(
    [(f"data_loader_{i}", DataLoader()) for i in range(n)] +
    [(f"processor_{i}", Processor()) for i in range(n)] +
    [(f"classifier_{i}", Classifier()) for i in range(n)] 
)

from time import time
start = time()
pipelines = repository.build_pipelines()
print(f"Built {len(pipelines)} pipelines in {time() - start:.2f} seconds")
# Out:
# Built 219200 pipelines in 1.45 seconds
