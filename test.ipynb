# %%
from pypekit import Task, Repository, CachedExecutor, Pipeline

class DataLoader(Task):
    input_types = ["source"]
    output_types = ["raw"]

    def run(self, _):
        print(f"Running DataLoader")
        return "output"

class Processor(Task):
    input_types = ["raw", "processed"]
    output_types = ["processed"]
        
    def run(self, _):
        print(f"Running Processor")
        return "output"

class Classifier(Task):
    input_types = ["raw", "processed"]
    output_types = ["sink", "processed"]
        
    def run(self, _):
        print(f"Running Classifier")
        return "output"
    
repository = Repository([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline_dict = repository.build_pipelines()
for pipeline in pipeline_dict.values():
    print(pipeline)

executor = CachedExecutor(pipeline_dict, verbose=True)
executor.run()

executor.results
# Out:
# Pipeline(id=a7612403579142e5958536942d43f41d, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=a98e56a0daff48dea1352eaccff40675, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=3040a46f932e4825aa413c634ed8fc6f, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=30228d4944464c6f9f0f9f7dad0a060b, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=1eb17b8c228b4c77b802f5823b220d07, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=f429dacff5e94526858a03e053eee4f6, tasks=['data_loader', 'processor_1', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=8071d9bc65f546a7ad9a50b5da29da19, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=715e5049b24c46afa80b9e0164f1c3cc, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=3a77e7a3b78a428ea08c8652ba6ff043, tasks=['data_loader', 'processor_1', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=b8f07145484d406ba39dad2f61d71eac, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=a0c8b75f90a64b8fb2055ecb4117fabc, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=f9b626c63e4c43eeac4c66b39aac432c, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=500bc3032bda44fc87f65dc6e6dfed01, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=1b4c0a8d19e64ee2ab480c70e915fa87, tasks=['data_loader', 'processor_2', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=21f1f57064024d4a9bf43c2606f4d170, tasks=['data_loader', 'processor_2', 'classifier_1'])
# Pipeline(id=5155af4e53134843a0573a9738ea9f88, tasks=['data_loader', 'processor_2', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=39938282f1d144dca011905aba9f385e, tasks=['data_loader', 'processor_2', 'classifier_1', 'classifier_2'])
# Pipeline(id=629e39fd9ac84a948dd249448886b7f2, tasks=['data_loader', 'processor_2', 'classifier_2'])
# Pipeline(id=a184740fea5c4f2db98ea962492b8b52, tasks=['data_loader', 'processor_2', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=fed0908370a24d5e9443f18ba5d5d602, tasks=['data_loader', 'processor_2', 'classifier_2', 'classifier_1'])
# Pipeline(id=ea9a12cbbfe240f4b2c55c0d9d2f4a09, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=a4f11698149f471fb4c3e2aa75056d49, tasks=['data_loader', 'classifier_1', 'processor_1', 'processor_2', 'classifier_2'])
# Pipeline(id=4c90209600844d8fa9578fea86e0d535, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=b66a52d319ed436c8222f1e095580bad, tasks=['data_loader', 'classifier_1', 'processor_2', 'processor_1', 'classifier_2'])
# Pipeline(id=022db36b94f14f3ba4ae578d37978558, tasks=['data_loader', 'classifier_1', 'processor_2', 'classifier_2'])
# Pipeline(id=b47a0f2085e84c2ba5701e9a5abf49e2, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=63a68cface85458e8b33700b8f58f1db, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=f7397e13f6ec4a379c41b1d06e1a4e7c, tasks=['data_loader', 'classifier_2', 'processor_1', 'processor_2', 'classifier_1'])
# Pipeline(id=87d664b7c73c4c7f85162eadb38fe551, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=3f590e23ac4343c281dade880dde944e, tasks=['data_loader', 'classifier_2', 'processor_2', 'processor_1', 'classifier_1'])
# Pipeline(id=292a4b260ab442059f1113f298dd26c4, tasks=['data_loader', 'classifier_2', 'processor_2', 'classifier_1'])
# Pipeline(id=4e2ecc8241d444d69f284a10867a6419, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Running DataLoader
# Running Processor
# Running Processor
# Running Classifier
# Pipeline a7612403579142e5958536942d43f41d completed.
# Running Classifier
# Pipeline a98e56a0daff48dea1352eaccff40675 completed.
# Running Classifier
# Pipeline 3040a46f932e4825aa413c634ed8fc6f completed.
# Running Classifier
# Pipeline 30228d4944464c6f9f0f9f7dad0a060b completed.
# Running Classifier
# Pipeline 1eb17b8c228b4c77b802f5823b220d07 completed.
# Running Processor
# Running Classifier
# Pipeline f429dacff5e94526858a03e053eee4f6 completed.
# Running Classifier
# Pipeline 8071d9bc65f546a7ad9a50b5da29da19 completed.
# Running Classifier
# Pipeline 715e5049b24c46afa80b9e0164f1c3cc completed.
# Running Processor
# Running Classifier
# Pipeline 3a77e7a3b78a428ea08c8652ba6ff043 completed.
# Running Classifier
# Pipeline b8f07145484d406ba39dad2f61d71eac completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline a0c8b75f90a64b8fb2055ecb4117fabc completed.
# Running Classifier
# Pipeline f9b626c63e4c43eeac4c66b39aac432c completed.
# Running Classifier
# Pipeline 500bc3032bda44fc87f65dc6e6dfed01 completed.
# Running Classifier
# Pipeline 1b4c0a8d19e64ee2ab480c70e915fa87 completed.
# Running Classifier
# Pipeline 21f1f57064024d4a9bf43c2606f4d170 completed.
# Running Processor
# Running Classifier
# Pipeline 5155af4e53134843a0573a9738ea9f88 completed.
# Running Classifier
# Pipeline 39938282f1d144dca011905aba9f385e completed.
# Running Classifier
# Pipeline 629e39fd9ac84a948dd249448886b7f2 completed.
# Running Processor
# Running Classifier
# Pipeline a184740fea5c4f2db98ea962492b8b52 completed.
# Running Classifier
# Pipeline fed0908370a24d5e9443f18ba5d5d602 completed.
# Running Classifier
# Pipeline ea9a12cbbfe240f4b2c55c0d9d2f4a09 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline a4f11698149f471fb4c3e2aa75056d49 completed.
# Running Classifier
# Pipeline 4c90209600844d8fa9578fea86e0d535 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline b66a52d319ed436c8222f1e095580bad completed.
# Running Classifier
# Pipeline 022db36b94f14f3ba4ae578d37978558 completed.
# Running Classifier
# Pipeline b47a0f2085e84c2ba5701e9a5abf49e2 completed.
# Running Classifier
# Pipeline 63a68cface85458e8b33700b8f58f1db completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline f7397e13f6ec4a379c41b1d06e1a4e7c completed.
# Running Classifier
# Pipeline 87d664b7c73c4c7f85162eadb38fe551 completed.
# Running Processor
# Running Processor
# Running Classifier
# Pipeline 3f590e23ac4343c281dade880dde944e completed.
# Running Classifier
# Pipeline 292a4b260ab442059f1113f298dd26c4 completed.
# Running Classifier
# Pipeline 4e2ecc8241d444d69f284a10867a6419 completed.
# {'a7612403579142e5958536942d43f41d': {'pipeline_id': 'a7612403579142e5958536942d43f41d',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_1']},
#  'a98e56a0daff48dea1352eaccff40675': {'pipeline_id': 'a98e56a0daff48dea1352eaccff40675',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_1',
#    'classifier_2']},
#  '3040a46f932e4825aa413c634ed8fc6f': {'pipeline_id': '3040a46f932e4825aa413c634ed8fc6f',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'processor_2', 'classifier_2']},
#  '30228d4944464c6f9f0f9f7dad0a060b': {'pipeline_id': '30228d4944464c6f9f0f9f7dad0a060b',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'processor_2',
#    'classifier_2',
#    'classifier_1']},
#  '1eb17b8c228b4c77b802f5823b220d07': {'pipeline_id': '1eb17b8c228b4c77b802f5823b220d07',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1']},
#  'f429dacff5e94526858a03e053eee4f6': {'pipeline_id': 'f429dacff5e94526858a03e053eee4f6',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_1',
#    'processor_2',
#    'classifier_2']},
#  '8071d9bc65f546a7ad9a50b5da29da19': {'pipeline_id': '8071d9bc65f546a7ad9a50b5da29da19',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_1', 'classifier_2']},
#  '715e5049b24c46afa80b9e0164f1c3cc': {'pipeline_id': '715e5049b24c46afa80b9e0164f1c3cc',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2']},
#  '3a77e7a3b78a428ea08c8652ba6ff043': {'pipeline_id': '3a77e7a3b78a428ea08c8652ba6ff043',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_1',
#    'classifier_2',
#    'processor_2',
#    'classifier_1']},
#  'b8f07145484d406ba39dad2f61d71eac': {'pipeline_id': 'b8f07145484d406ba39dad2f61d71eac',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_1', 'classifier_2', 'classifier_1']},
#  'a0c8b75f90a64b8fb2055ecb4117fabc': {'pipeline_id': 'a0c8b75f90a64b8fb2055ecb4117fabc',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_1']},
#  'f9b626c63e4c43eeac4c66b39aac432c': {'pipeline_id': 'f9b626c63e4c43eeac4c66b39aac432c',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_1',
#    'classifier_2']},
#  '500bc3032bda44fc87f65dc6e6dfed01': {'pipeline_id': '500bc3032bda44fc87f65dc6e6dfed01',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'processor_1', 'classifier_2']},
#  '1b4c0a8d19e64ee2ab480c70e915fa87': {'pipeline_id': '1b4c0a8d19e64ee2ab480c70e915fa87',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'processor_1',
#    'classifier_2',
#    'classifier_1']},
#  '21f1f57064024d4a9bf43c2606f4d170': {'pipeline_id': '21f1f57064024d4a9bf43c2606f4d170',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1']},
#  '5155af4e53134843a0573a9738ea9f88': {'pipeline_id': '5155af4e53134843a0573a9738ea9f88',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_1',
#    'processor_1',
#    'classifier_2']},
#  '39938282f1d144dca011905aba9f385e': {'pipeline_id': '39938282f1d144dca011905aba9f385e',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_1', 'classifier_2']},
#  '629e39fd9ac84a948dd249448886b7f2': {'pipeline_id': '629e39fd9ac84a948dd249448886b7f2',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2']},
#  'a184740fea5c4f2db98ea962492b8b52': {'pipeline_id': 'a184740fea5c4f2db98ea962492b8b52',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'processor_2',
#    'classifier_2',
#    'processor_1',
#    'classifier_1']},
#  'fed0908370a24d5e9443f18ba5d5d602': {'pipeline_id': 'fed0908370a24d5e9443f18ba5d5d602',
#   'output': 'output',
#   'tasks': ['data_loader', 'processor_2', 'classifier_2', 'classifier_1']},
#  'ea9a12cbbfe240f4b2c55c0d9d2f4a09': {'pipeline_id': 'ea9a12cbbfe240f4b2c55c0d9d2f4a09',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1']},
#  'a4f11698149f471fb4c3e2aa75056d49': {'pipeline_id': 'a4f11698149f471fb4c3e2aa75056d49',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_1',
#    'processor_2',
#    'classifier_2']},
#  '4c90209600844d8fa9578fea86e0d535': {'pipeline_id': '4c90209600844d8fa9578fea86e0d535',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'processor_1', 'classifier_2']},
#  'b66a52d319ed436c8222f1e095580bad': {'pipeline_id': 'b66a52d319ed436c8222f1e095580bad',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_1',
#    'processor_2',
#    'processor_1',
#    'classifier_2']},
#  '022db36b94f14f3ba4ae578d37978558': {'pipeline_id': '022db36b94f14f3ba4ae578d37978558',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'processor_2', 'classifier_2']},
#  'b47a0f2085e84c2ba5701e9a5abf49e2': {'pipeline_id': 'b47a0f2085e84c2ba5701e9a5abf49e2',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_1', 'classifier_2']},
#  '63a68cface85458e8b33700b8f58f1db': {'pipeline_id': '63a68cface85458e8b33700b8f58f1db',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2']},
#  'f7397e13f6ec4a379c41b1d06e1a4e7c': {'pipeline_id': 'f7397e13f6ec4a379c41b1d06e1a4e7c',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_1',
#    'processor_2',
#    'classifier_1']},
#  '87d664b7c73c4c7f85162eadb38fe551': {'pipeline_id': '87d664b7c73c4c7f85162eadb38fe551',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'processor_1', 'classifier_1']},
#  '3f590e23ac4343c281dade880dde944e': {'pipeline_id': '3f590e23ac4343c281dade880dde944e',
#   'output': 'output',
#   'tasks': ['data_loader',
#    'classifier_2',
#    'processor_2',
#    'processor_1',
#    'classifier_1']},
#  '292a4b260ab442059f1113f298dd26c4': {'pipeline_id': '292a4b260ab442059f1113f298dd26c4',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'processor_2', 'classifier_1']},
#  '4e2ecc8241d444d69f284a10867a6419': {'pipeline_id': '4e2ecc8241d444d69f284a10867a6419',
#   'output': 'output',
#   'tasks': ['data_loader', 'classifier_2', 'classifier_1']}}

# %%
n = 4

repository = Repository(
    [(f"data_loader_{i}", DataLoader()) for i in range(n)] +
    [(f"processor_{i}", Processor()) for i in range(n)] +
    [(f"classifier_{i}", Classifier()) for i in range(n)] 
)

from time import time
start = time()
pipelines = repository.build_pipelines()
print(f"Built {len(pipelines)} pipelines in {time() - start:.2f} seconds")
# Out:
# Built 219200 pipelines in 3.12 seconds

# %%
pipeline = Pipeline([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("processor_2", Processor()),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline
# Out:
# Pipeline(id=5920b0c97b864914a004c6a0a4702011, tasks=['data_loader', 'processor_1', 'processor_2', 'classifier_1', 'classifier_2'])

# %%
print(repository)
print(executor)
# Out:
# Repository(tasks=['data_loader_0', 'data_loader_1', 'data_loader_2', 'data_loader_3', 'processor_0', 'processor_1', 'processor_2', 'processor_3', 'classifier_0', 'classifier_1', 'classifier_2', 'classifier_3'], pipelines=219200)
# CachedExecutor(pipelines=32)

# %%
executor2 = CachedExecutor(pipeline_dict, cache=executor.cache, verbose=True)
executor2.run();
# Out:
# Pipeline a7612403579142e5958536942d43f41d completed.
# Pipeline a98e56a0daff48dea1352eaccff40675 completed.
# Pipeline 3040a46f932e4825aa413c634ed8fc6f completed.
# Pipeline 30228d4944464c6f9f0f9f7dad0a060b completed.
# Pipeline 1eb17b8c228b4c77b802f5823b220d07 completed.
# Pipeline f429dacff5e94526858a03e053eee4f6 completed.
# Pipeline 8071d9bc65f546a7ad9a50b5da29da19 completed.
# Pipeline 715e5049b24c46afa80b9e0164f1c3cc completed.
# Pipeline 3a77e7a3b78a428ea08c8652ba6ff043 completed.
# Pipeline b8f07145484d406ba39dad2f61d71eac completed.
# Pipeline a0c8b75f90a64b8fb2055ecb4117fabc completed.
# Pipeline f9b626c63e4c43eeac4c66b39aac432c completed.
# Pipeline 500bc3032bda44fc87f65dc6e6dfed01 completed.
# Pipeline 1b4c0a8d19e64ee2ab480c70e915fa87 completed.
# Pipeline 21f1f57064024d4a9bf43c2606f4d170 completed.
# Pipeline 5155af4e53134843a0573a9738ea9f88 completed.
# Pipeline 39938282f1d144dca011905aba9f385e completed.
# Pipeline 629e39fd9ac84a948dd249448886b7f2 completed.
# Pipeline a184740fea5c4f2db98ea962492b8b52 completed.
# Pipeline fed0908370a24d5e9443f18ba5d5d602 completed.
# Pipeline ea9a12cbbfe240f4b2c55c0d9d2f4a09 completed.
# Pipeline a4f11698149f471fb4c3e2aa75056d49 completed.
# Pipeline 4c90209600844d8fa9578fea86e0d535 completed.
# Pipeline b66a52d319ed436c8222f1e095580bad completed.
# Pipeline 022db36b94f14f3ba4ae578d37978558 completed.
# Pipeline b47a0f2085e84c2ba5701e9a5abf49e2 completed.
# Pipeline 63a68cface85458e8b33700b8f58f1db completed.
# Pipeline f7397e13f6ec4a379c41b1d06e1a4e7c completed.
# Pipeline 87d664b7c73c4c7f85162eadb38fe551 completed.
# Pipeline 3f590e23ac4343c281dade880dde944e completed.
# Pipeline 292a4b260ab442059f1113f298dd26c4 completed.
# Pipeline 4e2ecc8241d444d69f284a10867a6419 completed.

# %%
repository = Repository([
    ("data_loader", DataLoader()),
    ("processor_1", Processor()),
    ("pipeline", pipeline),
    ("classifier_1", Classifier()),
    ("classifier_2", Classifier()),
])
pipeline_dict = repository.build_pipelines()
for pipeline in pipeline_dict.values():
    print(pipeline)
# Out:
# Pipeline(id=a0ce7eaf5a514c7a955358cae0e9fb09, tasks=['data_loader', 'processor_1', 'classifier_1'])
# Pipeline(id=963cf51d19aa43b0981591b3ae30d1ae, tasks=['data_loader', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=fefaa0fb04f74c3da6ccb47f564146a3, tasks=['data_loader', 'processor_1', 'classifier_2'])
# Pipeline(id=8c26402c526641ceb5f6fed4d379b985, tasks=['data_loader', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=d0e20815eb2046c8ad1f6a9a16caa3c0, tasks=['data_loader', 'classifier_1'])
# Pipeline(id=7c80ccb74c644e3f928b3ab69338ce54, tasks=['data_loader', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=d5fa9ffd10084c1bb3a4dbe6913b1b50, tasks=['data_loader', 'classifier_1', 'classifier_2'])
# Pipeline(id=ec228608b6c34eb49a3ecb0926cc0f28, tasks=['data_loader', 'classifier_2'])
# Pipeline(id=38b8c2a3aecc4dea86ced6cfa746f3a8, tasks=['data_loader', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=2e505ab55b7d432396024aea9deaa4ee, tasks=['data_loader', 'classifier_2', 'classifier_1'])
# Pipeline(id=5d129d80c6ff4a7099c66d08ed0b8971, tasks=['pipeline'])
# Pipeline(id=13334643708d4e6f85b21d0d637c5dbc, tasks=['pipeline', 'processor_1', 'classifier_1'])
# Pipeline(id=8d0ff0e921304aca980efed3a28688dc, tasks=['pipeline', 'processor_1', 'classifier_1', 'classifier_2'])
# Pipeline(id=9e57566f03354513853b00c8254dea45, tasks=['pipeline', 'processor_1', 'classifier_2'])
# Pipeline(id=8db98db62a844a6287553217e397a5dd, tasks=['pipeline', 'processor_1', 'classifier_2', 'classifier_1'])
# Pipeline(id=adb0a22242184079b9819998cd104d89, tasks=['pipeline', 'classifier_1'])
# Pipeline(id=03efd1515e1f4cd8ae5b159632ed5336, tasks=['pipeline', 'classifier_1', 'processor_1', 'classifier_2'])
# Pipeline(id=a75deeddf9bd4af9b80c520428bfdd1d, tasks=['pipeline', 'classifier_1', 'classifier_2'])
# Pipeline(id=4fe1f4b7757246329f1eb6d18178eb66, tasks=['pipeline', 'classifier_2'])
# Pipeline(id=ced75a3030d9431b85f00bdc92f87911, tasks=['pipeline', 'classifier_2', 'processor_1', 'classifier_1'])
# Pipeline(id=49ec68bd7084470c87a84fe59fa018e8, tasks=['pipeline', 'classifier_2', 'classifier_1'])
